# %% [markdown]
# # Time Series Forecasting for Finance - Example
#
# This notebook demonstrates the basic usage of the time series forecasting framework.
#
# ## ⚠️ DISCLAIMER
# This is for research and educational purposes only. NOT investment advice.

# %%
import sys
from pathlib import Path

# Add src to path
sys.path.append(str(Path.cwd().parent / "src"))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from omegaconf import DictConfig

from data import DataLoader, FeatureEngineer, TimeSeriesSplitter
from models import ARIMAModel, XGBoostModel
from evaluation import ModelEvaluator
from backtest import Backtester
from utils import load_config, set_seed
